# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    #print(source_text.split('\n'))
    source_ids = [[source_vocab_to_int[word] for word in line.split()] for line in source_text.split('\n')]
    target_ids = [[target_vocab_to_int[word] for word in line.split()] for line in target_text.split('\n')]
    target_ids = [ line + [target_vocab_to_int['<EOS>']] for line in target_ids]
    return source_ids, target_ids

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    input_ = tf.placeholder(dtype=tf.int32, shape=[None, None], name='input')
    targets_ = tf.placeholder(dtype=tf.int32, shape=[None, None], name='target')
    lr = tf.placeholder(dtype=tf.float32, shape=None, name="learning_rate")
    keep_prob = tf.placeholder(dtype=tf.float32, shape=None, name='keep_prob')
    target_seq_length = tf.placeholder(dtype=tf.int32, shape=[None], name='target_sequence_length')
    max_target_seq_length = tf.reduce_max(target_seq_length, name='max_target_len')
    source_seq_length = tf.placeholder(dtype=tf.int32, shape=[None], name='source_sequence_length')
    
    return input_, targets_, lr, keep_prob, target_seq_length, max_target_seq_length, source_seq_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    #print(target_data, batch_size)
    go_id = target_vocab_to_int['<GO>']
    go_vector = tf.reshape([go_id for _ in range(batch_size)], (-1, 1))
    target_data = tf.concat([go_vector, target_data[:, :-1]], axis=1)
    
    return target_data

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
from tensorflow.python.layers.core import Dense
reload(tests)

def build_rnn(num_units, keep_prob):
    lstm = tf.contrib.rnn.LSTMCell(num_units)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob=1.0, output_keep_prob=keep_prob)
    return drop

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    #:param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    #print(source_sequence_length, rnn_inputs)
    embeds = tf.contrib.layers.embed_sequence(rnn_inputs, vocab_size=source_vocab_size, embed_dim=encoding_embedding_size)
    multi_cell = tf.contrib.rnn.MultiRNNCell([build_rnn(rnn_size, keep_prob) for _ in range(num_layers)])
    #initial_state = multi_cell.zero_state(source_sequence_length[0], tf.float32) ## THIS MIGHT BE TOTALLY WRONG
    outputs, state = tf.nn.dynamic_rnn(multi_cell, embeds, dtype=tf.float32)
    return outputs, state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length, time_major=False)
    basic_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, helper, encoder_state, output_layer)
    
    outputs, _ = tf.contrib.seq2seq.dynamic_decode(basic_decoder, maximum_iterations=max_summary_length, impute_finished=True)
    return outputs


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding # THIS DOESN"T EXIST I"LL MAKE A PULL REQUEST SOON
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    start_tokens = tf.constant([start_of_sequence_id for _ in range(batch_size)])
    greedy_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings, start_tokens, end_of_sequence_id)
    infer_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, greedy_helper, encoder_state, output_layer)
    outputs, _ = tf.contrib.seq2seq.dynamic_decode(infer_decoder, impute_finished=True, maximum_iterations=max_target_sequence_length)
    return outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def build_decoder_rnn(num_units, keep_prob):
    lstm = tf.contrib.rnn.LSTMCell(num_units)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob=1.0, output_keep_prob=keep_prob)
    return drop

def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    dec_cell = tf.contrib.rnn.MultiRNNCell([build_decoder_rnn(rnn_size, keep_prob) for _ in range(num_layers)])
    output_layer = Dense(target_vocab_size, kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    with tf.variable_scope("decode"):
        training_logits = decoding_layer_train(encoder_state, dec_cell, 
                                               dec_embed_input, target_sequence_length, 
                                               max_target_sequence_length, output_layer, 
                                               keep_prob) 
    
    with tf.variable_scope("decode", reuse=True):
        inference_logits = decoding_layer_infer(encoder_state, dec_cell, 
                                                dec_embeddings, target_vocab_to_int['<GO>'], 
                                                target_vocab_to_int['<EOS>'], max_target_sequence_length, 
                                                target_vocab_size, output_layer, batch_size, 
                                                keep_prob)
    
    return training_logits, inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    _, enc_state = encoding_layer(input_data, rnn_size, 
                                    num_layers, keep_prob,  
                                    source_sequence_length, 
                                    source_vocab_size, 
                                    enc_embedding_size)
    
    target_data = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    train, test = decoding_layer(target_data, enc_state, 
                                 target_sequence_length, 
                                 max_target_sentence_length, 
                                 rnn_size, num_layers, 
                                 target_vocab_to_int, 
                                 target_vocab_size, batch_size, 
                                 keep_prob, dec_embedding_size)
    
    
    return train, test


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 300
decoding_embedding_size = 300
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.5
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/538 - Train Accuracy: 0.2578, Validation Accuracy: 0.3466, Loss: 3.5700
# Epoch   0 Batch   20/538 - Train Accuracy: 0.3605, Validation Accuracy: 0.4038, Loss: 2.8214
# Epoch   0 Batch   30/538 - Train Accuracy: 0.4154, Validation Accuracy: 0.4780, Loss: 2.6226
# Epoch   0 Batch   40/538 - Train Accuracy: 0.5004, Validation Accuracy: 0.5075, Loss: 2.1824
# Epoch   0 Batch   50/538 - Train Accuracy: 0.5119, Validation Accuracy: 0.5430, Loss: 2.0851
# Epoch   0 Batch   60/538 - Train Accuracy: 0.4984, Validation Accuracy: 0.5407, Loss: 1.8622
# Epoch   0 Batch   70/538 - Train Accuracy: 0.5234, Validation Accuracy: 0.5430, Loss: 1.4714
# Epoch   0 Batch   80/538 - Train Accuracy: 0.3611, Validation Accuracy: 0.4192, Loss: 1.3228
# Epoch   0 Batch   90/538 - Train Accuracy: 0.4438, Validation Accuracy: 0.4631, Loss: 1.1232
# Epoch   0 Batch  100/538 - Train Accuracy: 0.5350, Validation Accuracy: 0.5575, Loss: 1.0065
# Epoch   0 Batch  110/538 - Train Accuracy: 0.5086, Validation Accuracy: 0.5668, Loss: 0.9751
# Epoch   0 Batch  120/538 - Train Accuracy: 0.5178, Validation Accuracy: 0.5682, Loss: 0.8730
# Epoch   0 Batch  130/538 - Train Accuracy: 0.5374, Validation Accuracy: 0.5554, Loss: 0.8326
# Epoch   0 Batch  140/538 - Train Accuracy: 0.5180, Validation Accuracy: 0.5845, Loss: 0.8726
# Epoch   0 Batch  150/538 - Train Accuracy: 0.5920, Validation Accuracy: 0.6049, Loss: 0.7907
# Epoch   0 Batch  160/538 - Train Accuracy: 0.5785, Validation Accuracy: 0.6088, Loss: 0.7280
# Epoch   0 Batch  170/538 - Train Accuracy: 0.5964, Validation Accuracy: 0.6039, Loss: 0.7290
# Epoch   0 Batch  180/538 - Train Accuracy: 0.6120, Validation Accuracy: 0.6037, Loss: 0.6982
# Epoch   0 Batch  190/538 - Train Accuracy: 0.6047, Validation Accuracy: 0.6227, Loss: 0.7098
# Epoch   0 Batch  200/538 - Train Accuracy: 0.6170, Validation Accuracy: 0.6197, Loss: 0.6679
# Epoch   0 Batch  210/538 - Train Accuracy: 0.6068, Validation Accuracy: 0.6314, Loss: 0.6501
# Epoch   0 Batch  220/538 - Train Accuracy: 0.5809, Validation Accuracy: 0.6282, Loss: 0.6353
# Epoch   0 Batch  230/538 - Train Accuracy: 0.6059, Validation Accuracy: 0.6461, Loss: 0.6384
# Epoch   0 Batch  240/538 - Train Accuracy: 0.6254, Validation Accuracy: 0.6477, Loss: 0.6141
# Epoch   0 Batch  250/538 - Train Accuracy: 0.6221, Validation Accuracy: 0.6417, Loss: 0.5981
# Epoch   0 Batch  260/538 - Train Accuracy: 0.6414, Validation Accuracy: 0.6522, Loss: 0.5705
# Epoch   0 Batch  270/538 - Train Accuracy: 0.6426, Validation Accuracy: 0.6639, Loss: 0.5774
# Epoch   0 Batch  280/538 - Train Accuracy: 0.6897, Validation Accuracy: 0.6628, Loss: 0.5286
# Epoch   0 Batch  290/538 - Train Accuracy: 0.6424, Validation Accuracy: 0.6625, Loss: 0.5318
# Epoch   0 Batch  300/538 - Train Accuracy: 0.6735, Validation Accuracy: 0.6681, Loss: 0.5300
# Epoch   0 Batch  310/538 - Train Accuracy: 0.6520, Validation Accuracy: 0.6665, Loss: 0.5255
# Epoch   0 Batch  320/538 - Train Accuracy: 0.6611, Validation Accuracy: 0.6822, Loss: 0.5106
# Epoch   0 Batch  330/538 - Train Accuracy: 0.6708, Validation Accuracy: 0.6713, Loss: 0.4841
# Epoch   0 Batch  340/538 - Train Accuracy: 0.6541, Validation Accuracy: 0.6852, Loss: 0.5140
# Epoch   0 Batch  350/538 - Train Accuracy: 0.6752, Validation Accuracy: 0.6786, Loss: 0.4805
# Epoch   0 Batch  360/538 - Train Accuracy: 0.6607, Validation Accuracy: 0.6916, Loss: 0.5005
# Epoch   0 Batch  370/538 - Train Accuracy: 0.6666, Validation Accuracy: 0.6939, Loss: 0.4854
# Epoch   0 Batch  380/538 - Train Accuracy: 0.6557, Validation Accuracy: 0.7061, Loss: 0.4523
# Epoch   0 Batch  390/538 - Train Accuracy: 0.7174, Validation Accuracy: 0.6887, Loss: 0.4415
# Epoch   0 Batch  400/538 - Train Accuracy: 0.6897, Validation Accuracy: 0.7017, Loss: 0.4460
# Epoch   0 Batch  410/538 - Train Accuracy: 0.6879, Validation Accuracy: 0.6999, Loss: 0.4464
# Epoch   0 Batch  420/538 - Train Accuracy: 0.6926, Validation Accuracy: 0.7168, Loss: 0.4320
# Epoch   0 Batch  430/538 - Train Accuracy: 0.7068, Validation Accuracy: 0.7179, Loss: 0.4229
# Epoch   0 Batch  440/538 - Train Accuracy: 0.6941, Validation Accuracy: 0.7196, Loss: 0.4317
# Epoch   0 Batch  450/538 - Train Accuracy: 0.7227, Validation Accuracy: 0.7200, Loss: 0.4054
# Epoch   0 Batch  460/538 - Train Accuracy: 0.6886, Validation Accuracy: 0.7342, Loss: 0.3887
# Epoch   0 Batch  470/538 - Train Accuracy: 0.7245, Validation Accuracy: 0.7349, Loss: 0.3711
# Epoch   0 Batch  480/538 - Train Accuracy: 0.7351, Validation Accuracy: 0.7346, Loss: 0.3633
# Epoch   0 Batch  490/538 - Train Accuracy: 0.7453, Validation Accuracy: 0.7491, Loss: 0.3481
# Epoch   0 Batch  500/538 - Train Accuracy: 0.7711, Validation Accuracy: 0.7504, Loss: 0.3117
# Epoch   0 Batch  510/538 - Train Accuracy: 0.7706, Validation Accuracy: 0.7480, Loss: 0.3253
# Epoch   0 Batch  520/538 - Train Accuracy: 0.7508, Validation Accuracy: 0.7450, Loss: 0.3350
# Epoch   0 Batch  530/538 - Train Accuracy: 0.7301, Validation Accuracy: 0.7440, Loss: 0.3442
# Epoch   1 Batch   10/538 - Train Accuracy: 0.7537, Validation Accuracy: 0.7610, Loss: 0.3039
# Epoch   1 Batch   20/538 - Train Accuracy: 0.7573, Validation Accuracy: 0.7868, Loss: 0.3041
# Epoch   1 Batch   30/538 - Train Accuracy: 0.7553, Validation Accuracy: 0.7905, Loss: 0.3042
# Epoch   1 Batch   40/538 - Train Accuracy: 0.8006, Validation Accuracy: 0.7757, Loss: 0.2524
# Epoch   1 Batch   50/538 - Train Accuracy: 0.7943, Validation Accuracy: 0.8042, Loss: 0.2751
# Epoch   1 Batch   60/538 - Train Accuracy: 0.8213, Validation Accuracy: 0.7978, Loss: 0.2643
# Epoch   1 Batch   70/538 - Train Accuracy: 0.7820, Validation Accuracy: 0.7729, Loss: 0.2477
# Epoch   1 Batch   80/538 - Train Accuracy: 0.7953, Validation Accuracy: 0.8161, Loss: 0.2564
# Epoch   1 Batch   90/538 - Train Accuracy: 0.7911, Validation Accuracy: 0.8081, Loss: 0.2501
# Epoch   1 Batch  100/538 - Train Accuracy: 0.8047, Validation Accuracy: 0.8089, Loss: 0.2245
# Epoch   1 Batch  110/538 - Train Accuracy: 0.8076, Validation Accuracy: 0.8093, Loss: 0.2478
# Epoch   1 Batch  120/538 - Train Accuracy: 0.8459, Validation Accuracy: 0.8031, Loss: 0.2139
# Epoch   1 Batch  130/538 - Train Accuracy: 0.8331, Validation Accuracy: 0.8038, Loss: 0.2115
# Epoch   1 Batch  140/538 - Train Accuracy: 0.8092, Validation Accuracy: 0.8464, Loss: 0.2346
# Epoch   1 Batch  150/538 - Train Accuracy: 0.8182, Validation Accuracy: 0.8319, Loss: 0.2147
# Epoch   1 Batch  160/538 - Train Accuracy: 0.8026, Validation Accuracy: 0.8184, Loss: 0.2002
# Epoch   1 Batch  170/538 - Train Accuracy: 0.8140, Validation Accuracy: 0.8251, Loss: 0.2099
# Epoch   1 Batch  180/538 - Train Accuracy: 0.8517, Validation Accuracy: 0.8221, Loss: 0.2016
# Epoch   1 Batch  190/538 - Train Accuracy: 0.8237, Validation Accuracy: 0.8448, Loss: 0.2325
# Epoch   1 Batch  200/538 - Train Accuracy: 0.8303, Validation Accuracy: 0.8439, Loss: 0.1846
# Epoch   1 Batch  210/538 - Train Accuracy: 0.8318, Validation Accuracy: 0.8493, Loss: 0.1921
# Epoch   1 Batch  220/538 - Train Accuracy: 0.8261, Validation Accuracy: 0.8409, Loss: 0.1814
# Epoch   1 Batch  230/538 - Train Accuracy: 0.8295, Validation Accuracy: 0.8366, Loss: 0.1861
# Epoch   1 Batch  240/538 - Train Accuracy: 0.8195, Validation Accuracy: 0.8528, Loss: 0.1875
# Epoch   1 Batch  250/538 - Train Accuracy: 0.8756, Validation Accuracy: 0.8555, Loss: 0.1688
# Epoch   1 Batch  260/538 - Train Accuracy: 0.8222, Validation Accuracy: 0.8448, Loss: 0.1746
# Epoch   1 Batch  270/538 - Train Accuracy: 0.8695, Validation Accuracy: 0.8677, Loss: 0.1602
# Epoch   1 Batch  280/538 - Train Accuracy: 0.8780, Validation Accuracy: 0.8688, Loss: 0.1463
# Epoch   1 Batch  290/538 - Train Accuracy: 0.8861, Validation Accuracy: 0.8659, Loss: 0.1581
# Epoch   1 Batch  300/538 - Train Accuracy: 0.8956, Validation Accuracy: 0.8697, Loss: 0.1610
# Epoch   1 Batch  310/538 - Train Accuracy: 0.9016, Validation Accuracy: 0.8933, Loss: 0.1643
# Epoch   1 Batch  320/538 - Train Accuracy: 0.8800, Validation Accuracy: 0.8826, Loss: 0.1460
# Epoch   1 Batch  330/538 - Train Accuracy: 0.8990, Validation Accuracy: 0.8810, Loss: 0.1421
# Epoch   1 Batch  340/538 - Train Accuracy: 0.8916, Validation Accuracy: 0.8904, Loss: 0.1475
# Epoch   1 Batch  350/538 - Train Accuracy: 0.8927, Validation Accuracy: 0.8699, Loss: 0.1523
# Epoch   1 Batch  360/538 - Train Accuracy: 0.8725, Validation Accuracy: 0.8979, Loss: 0.1491
# Epoch   1 Batch  370/538 - Train Accuracy: 0.9018, Validation Accuracy: 0.8786, Loss: 0.1460
# Epoch   1 Batch  380/538 - Train Accuracy: 0.8684, Validation Accuracy: 0.8972, Loss: 0.1410
# Epoch   1 Batch  390/538 - Train Accuracy: 0.8953, Validation Accuracy: 0.8855, Loss: 0.1272
# Epoch   1 Batch  400/538 - Train Accuracy: 0.9079, Validation Accuracy: 0.8864, Loss: 0.1389
# Epoch   1 Batch  410/538 - Train Accuracy: 0.8979, Validation Accuracy: 0.8912, Loss: 0.1506
# Epoch   1 Batch  420/538 - Train Accuracy: 0.9055, Validation Accuracy: 0.8864, Loss: 0.1385
# Epoch   1 Batch  430/538 - Train Accuracy: 0.8834, Validation Accuracy: 0.8944, Loss: 0.1298
# Epoch   1 Batch  440/538 - Train Accuracy: 0.8980, Validation Accuracy: 0.8979, Loss: 0.1433
# Epoch   1 Batch  450/538 - Train Accuracy: 0.8890, Validation Accuracy: 0.8920, Loss: 0.1500
# Epoch   1 Batch  460/538 - Train Accuracy: 0.8815, Validation Accuracy: 0.8807, Loss: 0.1207
# Epoch   1 Batch  470/538 - Train Accuracy: 0.9057, Validation Accuracy: 0.8991, Loss: 0.1231
# Epoch   1 Batch  480/538 - Train Accuracy: 0.9038, Validation Accuracy: 0.8935, Loss: 0.1170
# Epoch   1 Batch  490/538 - Train Accuracy: 0.9109, Validation Accuracy: 0.8935, Loss: 0.1103
# Epoch   1 Batch  500/538 - Train Accuracy: 0.9100, Validation Accuracy: 0.8771, Loss: 0.0994
# Epoch   1 Batch  510/538 - Train Accuracy: 0.9111, Validation Accuracy: 0.9118, Loss: 0.1123
# Epoch   1 Batch  520/538 - Train Accuracy: 0.8957, Validation Accuracy: 0.9032, Loss: 0.1120
# Epoch   1 Batch  530/538 - Train Accuracy: 0.8846, Validation Accuracy: 0.8993, Loss: 0.1137
# Epoch   2 Batch   10/538 - Train Accuracy: 0.8807, Validation Accuracy: 0.9034, Loss: 0.1188
# Epoch   2 Batch   20/538 - Train Accuracy: 0.8960, Validation Accuracy: 0.9064, Loss: 0.1134
# Epoch   2 Batch   30/538 - Train Accuracy: 0.8900, Validation Accuracy: 0.9050, Loss: 0.1159
# Epoch   2 Batch   40/538 - Train Accuracy: 0.9316, Validation Accuracy: 0.9007, Loss: 0.0810
# Epoch   2 Batch   50/538 - Train Accuracy: 0.9207, Validation Accuracy: 0.9006, Loss: 0.0956
# Epoch   2 Batch   60/538 - Train Accuracy: 0.9191, Validation Accuracy: 0.8938, Loss: 0.0971
# Epoch   2 Batch   70/538 - Train Accuracy: 0.9167, Validation Accuracy: 0.9002, Loss: 0.0945
# Epoch   2 Batch   80/538 - Train Accuracy: 0.9156, Validation Accuracy: 0.9094, Loss: 0.0994
# Epoch   2 Batch   90/538 - Train Accuracy: 0.8906, Validation Accuracy: 0.9066, Loss: 0.1018
# Epoch   2 Batch  100/538 - Train Accuracy: 0.9172, Validation Accuracy: 0.9103, Loss: 0.0852
# Epoch   2 Batch  110/538 - Train Accuracy: 0.8951, Validation Accuracy: 0.8968, Loss: 0.0987
# Epoch   2 Batch  120/538 - Train Accuracy: 0.9295, Validation Accuracy: 0.9009, Loss: 0.0769
# Epoch   2 Batch  130/538 - Train Accuracy: 0.9275, Validation Accuracy: 0.9015, Loss: 0.0815
# Epoch   2 Batch  140/538 - Train Accuracy: 0.9086, Validation Accuracy: 0.9229, Loss: 0.1096
# Epoch   2 Batch  150/538 - Train Accuracy: 0.9293, Validation Accuracy: 0.9066, Loss: 0.0878
# Epoch   2 Batch  160/538 - Train Accuracy: 0.8873, Validation Accuracy: 0.9252, Loss: 0.0855
# Epoch   2 Batch  170/538 - Train Accuracy: 0.9204, Validation Accuracy: 0.9047, Loss: 0.0910
# Epoch   2 Batch  180/538 - Train Accuracy: 0.9312, Validation Accuracy: 0.9087, Loss: 0.0951
# Epoch   2 Batch  190/538 - Train Accuracy: 0.8917, Validation Accuracy: 0.9023, Loss: 0.1097
# Epoch   2 Batch  200/538 - Train Accuracy: 0.9229, Validation Accuracy: 0.9116, Loss: 0.0804
# Epoch   2 Batch  210/538 - Train Accuracy: 0.9144, Validation Accuracy: 0.9066, Loss: 0.0840
# Epoch   2 Batch  220/538 - Train Accuracy: 0.9204, Validation Accuracy: 0.9064, Loss: 0.0880
# Epoch   2 Batch  230/538 - Train Accuracy: 0.9199, Validation Accuracy: 0.9116, Loss: 0.0859
# Epoch   2 Batch  240/538 - Train Accuracy: 0.9316, Validation Accuracy: 0.9110, Loss: 0.0929
# Epoch   2 Batch  250/538 - Train Accuracy: 0.9162, Validation Accuracy: 0.8904, Loss: 0.0856
# Epoch   2 Batch  260/538 - Train Accuracy: 0.8966, Validation Accuracy: 0.9226, Loss: 0.0868
# Epoch   2 Batch  270/538 - Train Accuracy: 0.9221, Validation Accuracy: 0.9116, Loss: 0.0760
# Epoch   2 Batch  280/538 - Train Accuracy: 0.9422, Validation Accuracy: 0.9018, Loss: 0.0674
# Epoch   2 Batch  290/538 - Train Accuracy: 0.9313, Validation Accuracy: 0.8991, Loss: 0.0706
# Epoch   2 Batch  300/538 - Train Accuracy: 0.9355, Validation Accuracy: 0.9073, Loss: 0.0883
# Epoch   2 Batch  310/538 - Train Accuracy: 0.9414, Validation Accuracy: 0.9189, Loss: 0.0930
# Epoch   2 Batch  320/538 - Train Accuracy: 0.9208, Validation Accuracy: 0.9249, Loss: 0.0775
# Epoch   2 Batch  330/538 - Train Accuracy: 0.9485, Validation Accuracy: 0.9102, Loss: 0.0696
# Epoch   2 Batch  340/538 - Train Accuracy: 0.9207, Validation Accuracy: 0.9178, Loss: 0.0854
# Epoch   2 Batch  350/538 - Train Accuracy: 0.9249, Validation Accuracy: 0.9148, Loss: 0.0900
# Epoch   2 Batch  360/538 - Train Accuracy: 0.9074, Validation Accuracy: 0.9203, Loss: 0.0777
# Epoch   2 Batch  370/538 - Train Accuracy: 0.9281, Validation Accuracy: 0.9153, Loss: 0.0789
# Epoch   2 Batch  380/538 - Train Accuracy: 0.9211, Validation Accuracy: 0.9082, Loss: 0.0721
# Epoch   2 Batch  390/538 - Train Accuracy: 0.9314, Validation Accuracy: 0.9157, Loss: 0.0653
# Epoch   2 Batch  400/538 - Train Accuracy: 0.9394, Validation Accuracy: 0.9226, Loss: 0.0772
# Epoch   2 Batch  410/538 - Train Accuracy: 0.9424, Validation Accuracy: 0.9309, Loss: 0.0772
# Epoch   2 Batch  420/538 - Train Accuracy: 0.9371, Validation Accuracy: 0.9270, Loss: 0.0757
# Epoch   2 Batch  430/538 - Train Accuracy: 0.9129, Validation Accuracy: 0.9116, Loss: 0.0697
# Epoch   2 Batch  440/538 - Train Accuracy: 0.9174, Validation Accuracy: 0.9343, Loss: 0.0784
# Epoch   2 Batch  450/538 - Train Accuracy: 0.9009, Validation Accuracy: 0.9185, Loss: 0.0912
# Epoch   2 Batch  460/538 - Train Accuracy: 0.9051, Validation Accuracy: 0.9109, Loss: 0.0857
# Epoch   2 Batch  470/538 - Train Accuracy: 0.9304, Validation Accuracy: 0.9249, Loss: 0.0840
# Epoch   2 Batch  480/538 - Train Accuracy: 0.9321, Validation Accuracy: 0.9004, Loss: 0.0736
# Epoch   2 Batch  490/538 - Train Accuracy: 0.9368, Validation Accuracy: 0.9086, Loss: 0.0653
# Epoch   2 Batch  500/538 - Train Accuracy: 0.9411, Validation Accuracy: 0.9277, Loss: 0.0628
# Epoch   2 Batch  510/538 - Train Accuracy: 0.9327, Validation Accuracy: 0.9281, Loss: 0.0750
# Epoch   2 Batch  520/538 - Train Accuracy: 0.9447, Validation Accuracy: 0.9219, Loss: 0.0685
# Epoch   2 Batch  530/538 - Train Accuracy: 0.9070, Validation Accuracy: 0.9265, Loss: 0.0915
# Epoch   3 Batch   10/538 - Train Accuracy: 0.8898, Validation Accuracy: 0.9134, Loss: 0.0820
# Epoch   3 Batch   20/538 - Train Accuracy: 0.9154, Validation Accuracy: 0.9247, Loss: 0.0714
# Epoch   3 Batch   30/538 - Train Accuracy: 0.9119, Validation Accuracy: 0.9228, Loss: 0.0779
# Epoch   3 Batch   40/538 - Train Accuracy: 0.9320, Validation Accuracy: 0.9247, Loss: 0.0647
# Epoch   3 Batch   50/538 - Train Accuracy: 0.9346, Validation Accuracy: 0.9272, Loss: 0.0708
# Epoch   3 Batch   60/538 - Train Accuracy: 0.9395, Validation Accuracy: 0.9320, Loss: 0.0739
# Epoch   3 Batch   70/538 - Train Accuracy: 0.9219, Validation Accuracy: 0.9233, Loss: 0.0711
# Epoch   3 Batch   80/538 - Train Accuracy: 0.9254, Validation Accuracy: 0.9185, Loss: 0.0781
# Epoch   3 Batch   90/538 - Train Accuracy: 0.9226, Validation Accuracy: 0.9357, Loss: 0.0788
# Epoch   3 Batch  100/538 - Train Accuracy: 0.9412, Validation Accuracy: 0.9281, Loss: 0.0681
# Epoch   3 Batch  110/538 - Train Accuracy: 0.9301, Validation Accuracy: 0.9354, Loss: 0.0776
# Epoch   3 Batch  120/538 - Train Accuracy: 0.9451, Validation Accuracy: 0.9213, Loss: 0.0559
# Epoch   3 Batch  130/538 - Train Accuracy: 0.9364, Validation Accuracy: 0.9371, Loss: 0.0632
# Epoch   3 Batch  140/538 - Train Accuracy: 0.9229, Validation Accuracy: 0.9190, Loss: 0.0888
# Epoch   3 Batch  150/538 - Train Accuracy: 0.9377, Validation Accuracy: 0.9265, Loss: 0.0632
# Epoch   3 Batch  160/538 - Train Accuracy: 0.9068, Validation Accuracy: 0.9355, Loss: 0.0650
# Epoch   3 Batch  170/538 - Train Accuracy: 0.9286, Validation Accuracy: 0.9180, Loss: 0.0673
# Epoch   3 Batch  180/538 - Train Accuracy: 0.9349, Validation Accuracy: 0.9237, Loss: 0.0660
# Epoch   3 Batch  190/538 - Train Accuracy: 0.9180, Validation Accuracy: 0.9251, Loss: 0.0872
# Epoch   3 Batch  200/538 - Train Accuracy: 0.9404, Validation Accuracy: 0.9233, Loss: 0.0650
# Epoch   3 Batch  210/538 - Train Accuracy: 0.9360, Validation Accuracy: 0.9244, Loss: 0.0688
# Epoch   3 Batch  220/538 - Train Accuracy: 0.9232, Validation Accuracy: 0.9160, Loss: 0.0748
# Epoch   3 Batch  230/538 - Train Accuracy: 0.9361, Validation Accuracy: 0.9231, Loss: 0.0690
# Epoch   3 Batch  240/538 - Train Accuracy: 0.9209, Validation Accuracy: 0.9345, Loss: 0.0794
# Epoch   3 Batch  250/538 - Train Accuracy: 0.9375, Validation Accuracy: 0.9325, Loss: 0.0669
# Epoch   3 Batch  260/538 - Train Accuracy: 0.9057, Validation Accuracy: 0.9148, Loss: 0.0716
# Epoch   3 Batch  270/538 - Train Accuracy: 0.9242, Validation Accuracy: 0.9322, Loss: 0.0702
# Epoch   3 Batch  280/538 - Train Accuracy: 0.9366, Validation Accuracy: 0.9141, Loss: 0.0602
# Epoch   3 Batch  290/538 - Train Accuracy: 0.9359, Validation Accuracy: 0.9295, Loss: 0.0612
# Epoch   3 Batch  300/538 - Train Accuracy: 0.9226, Validation Accuracy: 0.9290, Loss: 0.0800
# Epoch   3 Batch  310/538 - Train Accuracy: 0.9434, Validation Accuracy: 0.9347, Loss: 0.0748
# Epoch   3 Batch  320/538 - Train Accuracy: 0.9237, Validation Accuracy: 0.9393, Loss: 0.0641
# Epoch   3 Batch  330/538 - Train Accuracy: 0.9542, Validation Accuracy: 0.9283, Loss: 0.0566
# Epoch   3 Batch  340/538 - Train Accuracy: 0.9205, Validation Accuracy: 0.9425, Loss: 0.0707
# Epoch   3 Batch  350/538 - Train Accuracy: 0.9490, Validation Accuracy: 0.9352, Loss: 0.0718
# Epoch   3 Batch  360/538 - Train Accuracy: 0.9256, Validation Accuracy: 0.9395, Loss: 0.0626
# Epoch   3 Batch  370/538 - Train Accuracy: 0.9383, Validation Accuracy: 0.9176, Loss: 0.0611
# Epoch   3 Batch  380/538 - Train Accuracy: 0.9250, Validation Accuracy: 0.9235, Loss: 0.0577
# Epoch   3 Batch  390/538 - Train Accuracy: 0.9310, Validation Accuracy: 0.9279, Loss: 0.0518
# Epoch   3 Batch  400/538 - Train Accuracy: 0.9260, Validation Accuracy: 0.9439, Loss: 0.0699
# Epoch   3 Batch  410/538 - Train Accuracy: 0.9393, Validation Accuracy: 0.9366, Loss: 0.0699
# Epoch   3 Batch  420/538 - Train Accuracy: 0.9381, Validation Accuracy: 0.9213, Loss: 0.0661
# Epoch   3 Batch  430/538 - Train Accuracy: 0.9273, Validation Accuracy: 0.9242, Loss: 0.0670
# Epoch   3 Batch  440/538 - Train Accuracy: 0.9361, Validation Accuracy: 0.9194, Loss: 0.0763
# Epoch   3 Batch  450/538 - Train Accuracy: 0.9146, Validation Accuracy: 0.9210, Loss: 0.0820
# Epoch   3 Batch  460/538 - Train Accuracy: 0.9120, Validation Accuracy: 0.9400, Loss: 0.0750
# Epoch   3 Batch  470/538 - Train Accuracy: 0.9302, Validation Accuracy: 0.9368, Loss: 0.0684
# Epoch   3 Batch  480/538 - Train Accuracy: 0.9379, Validation Accuracy: 0.9183, Loss: 0.0632
# Epoch   3 Batch  490/538 - Train Accuracy: 0.9276, Validation Accuracy: 0.9263, Loss: 0.0618
# Epoch   3 Batch  500/538 - Train Accuracy: 0.9460, Validation Accuracy: 0.9219, Loss: 0.0523
# Epoch   3 Batch  510/538 - Train Accuracy: 0.9472, Validation Accuracy: 0.9260, Loss: 0.0599
# Epoch   3 Batch  520/538 - Train Accuracy: 0.9445, Validation Accuracy: 0.9252, Loss: 0.0621
# Epoch   3 Batch  530/538 - Train Accuracy: 0.9146, Validation Accuracy: 0.9428, Loss: 0.0695
# Epoch   4 Batch   10/538 - Train Accuracy: 0.9264, Validation Accuracy: 0.9251, Loss: 0.0793
# Epoch   4 Batch   20/538 - Train Accuracy: 0.9394, Validation Accuracy: 0.9290, Loss: 0.0647
# Epoch   4 Batch   30/538 - Train Accuracy: 0.9172, Validation Accuracy: 0.9181, Loss: 0.0791
# Epoch   4 Batch   40/538 - Train Accuracy: 0.9284, Validation Accuracy: 0.9252, Loss: 0.0670
# Epoch   4 Batch   50/538 - Train Accuracy: 0.9340, Validation Accuracy: 0.9268, Loss: 0.0631
# Epoch   4 Batch   60/538 - Train Accuracy: 0.9363, Validation Accuracy: 0.9366, Loss: 0.0614
# Epoch   4 Batch   70/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9277, Loss: 0.0617
# Epoch   4 Batch   80/538 - Train Accuracy: 0.9354, Validation Accuracy: 0.9288, Loss: 0.0699
# Epoch   4 Batch   90/538 - Train Accuracy: 0.9394, Validation Accuracy: 0.9284, Loss: 0.0695
# Epoch   4 Batch  100/538 - Train Accuracy: 0.9482, Validation Accuracy: 0.9286, Loss: 0.0563
# Epoch   4 Batch  110/538 - Train Accuracy: 0.9232, Validation Accuracy: 0.9148, Loss: 0.0637
# Epoch   4 Batch  120/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9274, Loss: 0.0490
# Epoch   4 Batch  130/538 - Train Accuracy: 0.9474, Validation Accuracy: 0.9316, Loss: 0.0588
# Epoch   4 Batch  140/538 - Train Accuracy: 0.9096, Validation Accuracy: 0.9251, Loss: 0.0744
# Epoch   4 Batch  150/538 - Train Accuracy: 0.9385, Validation Accuracy: 0.9284, Loss: 0.0515
# Epoch   4 Batch  160/538 - Train Accuracy: 0.9208, Validation Accuracy: 0.9203, Loss: 0.0593
# Epoch   4 Batch  170/538 - Train Accuracy: 0.9336, Validation Accuracy: 0.9277, Loss: 0.0623
# Epoch   4 Batch  180/538 - Train Accuracy: 0.9425, Validation Accuracy: 0.9263, Loss: 0.0657
# Epoch   4 Batch  190/538 - Train Accuracy: 0.9217, Validation Accuracy: 0.9197, Loss: 0.0776
# Epoch   4 Batch  200/538 - Train Accuracy: 0.9357, Validation Accuracy: 0.9247, Loss: 0.0556
# Epoch   4 Batch  210/538 - Train Accuracy: 0.9308, Validation Accuracy: 0.9173, Loss: 0.0653
# Epoch   4 Batch  220/538 - Train Accuracy: 0.9221, Validation Accuracy: 0.9260, Loss: 0.0646
# Epoch   4 Batch  230/538 - Train Accuracy: 0.9355, Validation Accuracy: 0.9355, Loss: 0.0672
# Epoch   4 Batch  240/538 - Train Accuracy: 0.9242, Validation Accuracy: 0.9265, Loss: 0.0740
# Epoch   4 Batch  250/538 - Train Accuracy: 0.9365, Validation Accuracy: 0.9306, Loss: 0.0514
# Epoch   4 Batch  260/538 - Train Accuracy: 0.9020, Validation Accuracy: 0.9327, Loss: 0.0739
# Epoch   4 Batch  270/538 - Train Accuracy: 0.9213, Validation Accuracy: 0.9409, Loss: 0.0652
# Epoch   4 Batch  280/538 - Train Accuracy: 0.9340, Validation Accuracy: 0.9338, Loss: 0.0551
# Epoch   4 Batch  290/538 - Train Accuracy: 0.9357, Validation Accuracy: 0.9268, Loss: 0.0601
# Epoch   4 Batch  300/538 - Train Accuracy: 0.9368, Validation Accuracy: 0.9178, Loss: 0.0691
# Epoch   4 Batch  310/538 - Train Accuracy: 0.9488, Validation Accuracy: 0.9416, Loss: 0.0773
# Epoch   4 Batch  320/538 - Train Accuracy: 0.9312, Validation Accuracy: 0.9437, Loss: 0.0625
# Epoch   4 Batch  330/538 - Train Accuracy: 0.9576, Validation Accuracy: 0.9183, Loss: 0.0590
# Epoch   4 Batch  340/538 - Train Accuracy: 0.9229, Validation Accuracy: 0.9324, Loss: 0.0725
# Epoch   4 Batch  350/538 - Train Accuracy: 0.9401, Validation Accuracy: 0.9316, Loss: 0.0705
# Epoch   4 Batch  360/538 - Train Accuracy: 0.9404, Validation Accuracy: 0.9341, Loss: 0.0611
# Epoch   4 Batch  370/538 - Train Accuracy: 0.9445, Validation Accuracy: 0.9325, Loss: 0.0676
# Epoch   4 Batch  380/538 - Train Accuracy: 0.9227, Validation Accuracy: 0.9430, Loss: 0.0597
# Epoch   4 Batch  390/538 - Train Accuracy: 0.9414, Validation Accuracy: 0.9432, Loss: 0.0525
# Epoch   4 Batch  400/538 - Train Accuracy: 0.9479, Validation Accuracy: 0.9377, Loss: 0.0656
# Epoch   4 Batch  410/538 - Train Accuracy: 0.9525, Validation Accuracy: 0.9370, Loss: 0.0700
# Epoch   4 Batch  420/538 - Train Accuracy: 0.9520, Validation Accuracy: 0.9299, Loss: 0.0542
# Epoch   4 Batch  430/538 - Train Accuracy: 0.9197, Validation Accuracy: 0.9265, Loss: 0.0609
# Epoch   4 Batch  440/538 - Train Accuracy: 0.9357, Validation Accuracy: 0.9224, Loss: 0.0777
# Epoch   4 Batch  450/538 - Train Accuracy: 0.9148, Validation Accuracy: 0.9274, Loss: 0.0864
# Epoch   4 Batch  460/538 - Train Accuracy: 0.9208, Validation Accuracy: 0.9350, Loss: 0.0748
# Epoch   4 Batch  470/538 - Train Accuracy: 0.9412, Validation Accuracy: 0.9254, Loss: 0.0616
# Epoch   4 Batch  480/538 - Train Accuracy: 0.9360, Validation Accuracy: 0.9258, Loss: 0.0609
# Epoch   4 Batch  490/538 - Train Accuracy: 0.9466, Validation Accuracy: 0.9368, Loss: 0.0669
# Epoch   4 Batch  500/538 - Train Accuracy: 0.9480, Validation Accuracy: 0.9318, Loss: 0.0470
# Epoch   4 Batch  510/538 - Train Accuracy: 0.9420, Validation Accuracy: 0.9345, Loss: 0.0627
# Epoch   4 Batch  520/538 - Train Accuracy: 0.9539, Validation Accuracy: 0.9375, Loss: 0.0588
# Epoch   4 Batch  530/538 - Train Accuracy: 0.9238, Validation Accuracy: 0.9274, Loss: 0.0730
# Epoch   5 Batch   10/538 - Train Accuracy: 0.9201, Validation Accuracy: 0.9226, Loss: 0.0779
# Epoch   5 Batch   20/538 - Train Accuracy: 0.9321, Validation Accuracy: 0.9267, Loss: 0.0627
# Epoch   5 Batch   30/538 - Train Accuracy: 0.9221, Validation Accuracy: 0.9324, Loss: 0.0826
# Epoch   5 Batch   40/538 - Train Accuracy: 0.9395, Validation Accuracy: 0.9377, Loss: 0.0514
# Epoch   5 Batch   50/538 - Train Accuracy: 0.9189, Validation Accuracy: 0.9249, Loss: 0.0568
# Epoch   5 Batch   60/538 - Train Accuracy: 0.9461, Validation Accuracy: 0.9274, Loss: 0.0686
# Epoch   5 Batch   70/538 - Train Accuracy: 0.9286, Validation Accuracy: 0.9203, Loss: 0.0661
# Epoch   5 Batch   80/538 - Train Accuracy: 0.9391, Validation Accuracy: 0.9377, Loss: 0.0685
# Epoch   5 Batch   90/538 - Train Accuracy: 0.9234, Validation Accuracy: 0.9315, Loss: 0.0841
# Epoch   5 Batch  100/538 - Train Accuracy: 0.9473, Validation Accuracy: 0.9393, Loss: 0.0502
# Epoch   5 Batch  110/538 - Train Accuracy: 0.9326, Validation Accuracy: 0.9357, Loss: 0.0692
# Epoch   5 Batch  120/538 - Train Accuracy: 0.9508, Validation Accuracy: 0.9386, Loss: 0.0578
# Epoch   5 Batch  130/538 - Train Accuracy: 0.9390, Validation Accuracy: 0.9421, Loss: 0.0619
# Epoch   5 Batch  140/538 - Train Accuracy: 0.9111, Validation Accuracy: 0.9320, Loss: 0.0895
# Epoch   5 Batch  150/538 - Train Accuracy: 0.9463, Validation Accuracy: 0.9308, Loss: 0.0536
# Epoch   5 Batch  160/538 - Train Accuracy: 0.9057, Validation Accuracy: 0.9272, Loss: 0.0619
# Epoch   5 Batch  170/538 - Train Accuracy: 0.9306, Validation Accuracy: 0.9267, Loss: 0.0643
# Epoch   5 Batch  180/538 - Train Accuracy: 0.9336, Validation Accuracy: 0.9363, Loss: 0.0699
# Epoch   5 Batch  190/538 - Train Accuracy: 0.9234, Validation Accuracy: 0.9281, Loss: 0.0922
# Epoch   5 Batch  200/538 - Train Accuracy: 0.9332, Validation Accuracy: 0.9091, Loss: 0.0638
# Epoch   5 Batch  210/538 - Train Accuracy: 0.9297, Validation Accuracy: 0.9194, Loss: 0.0701
# Epoch   5 Batch  220/538 - Train Accuracy: 0.9217, Validation Accuracy: 0.9217, Loss: 0.0723
# Epoch   5 Batch  230/538 - Train Accuracy: 0.9322, Validation Accuracy: 0.9370, Loss: 0.0653
# Epoch   5 Batch  240/538 - Train Accuracy: 0.9250, Validation Accuracy: 0.9425, Loss: 0.0868
# Epoch   5 Batch  250/538 - Train Accuracy: 0.9346, Validation Accuracy: 0.9244, Loss: 0.0673
# Epoch   5 Batch  260/538 - Train Accuracy: 0.9141, Validation Accuracy: 0.9482, Loss: 0.0717
# Epoch   5 Batch  270/538 - Train Accuracy: 0.9291, Validation Accuracy: 0.9480, Loss: 0.0731
# Epoch   5 Batch  280/538 - Train Accuracy: 0.9308, Validation Accuracy: 0.9277, Loss: 0.0601
# Epoch   5 Batch  290/538 - Train Accuracy: 0.9381, Validation Accuracy: 0.9277, Loss: 0.0602
# Epoch   5 Batch  300/538 - Train Accuracy: 0.9375, Validation Accuracy: 0.9402, Loss: 0.0647
# Epoch   5 Batch  310/538 - Train Accuracy: 0.9492, Validation Accuracy: 0.9498, Loss: 0.0675
# Epoch   5 Batch  320/538 - Train Accuracy: 0.9278, Validation Accuracy: 0.9355, Loss: 0.0564
# Epoch   5 Batch  330/538 - Train Accuracy: 0.9513, Validation Accuracy: 0.9363, Loss: 0.0598
# Epoch   5 Batch  340/538 - Train Accuracy: 0.9137, Validation Accuracy: 0.9359, Loss: 0.0719
# Epoch   5 Batch  350/538 - Train Accuracy: 0.9507, Validation Accuracy: 0.9334, Loss: 0.0678
# Epoch   5 Batch  360/538 - Train Accuracy: 0.9301, Validation Accuracy: 0.9247, Loss: 0.0576
# Epoch   5 Batch  370/538 - Train Accuracy: 0.9385, Validation Accuracy: 0.9315, Loss: 0.0606
# Epoch   5 Batch  380/538 - Train Accuracy: 0.9383, Validation Accuracy: 0.9396, Loss: 0.0633
# Epoch   5 Batch  390/538 - Train Accuracy: 0.9503, Validation Accuracy: 0.9339, Loss: 0.0519
# Epoch   5 Batch  400/538 - Train Accuracy: 0.9407, Validation Accuracy: 0.9414, Loss: 0.0647
# Epoch   5 Batch  410/538 - Train Accuracy: 0.9447, Validation Accuracy: 0.9331, Loss: 0.0808
# Epoch   5 Batch  420/538 - Train Accuracy: 0.9305, Validation Accuracy: 0.9490, Loss: 0.0660
# Epoch   5 Batch  430/538 - Train Accuracy: 0.9158, Validation Accuracy: 0.9435, Loss: 0.0617
# Epoch   5 Batch  440/538 - Train Accuracy: 0.9285, Validation Accuracy: 0.9387, Loss: 0.0941
# Epoch   5 Batch  450/538 - Train Accuracy: 0.9103, Validation Accuracy: 0.9380, Loss: 0.0809
# Epoch   5 Batch  460/538 - Train Accuracy: 0.9200, Validation Accuracy: 0.9391, Loss: 0.0879
# Epoch   5 Batch  470/538 - Train Accuracy: 0.9375, Validation Accuracy: 0.9272, Loss: 0.0732
# Epoch   5 Batch  480/538 - Train Accuracy: 0.9342, Validation Accuracy: 0.9315, Loss: 0.0701
# Epoch   5 Batch  490/538 - Train Accuracy: 0.9379, Validation Accuracy: 0.9411, Loss: 0.0635
# Epoch   5 Batch  500/538 - Train Accuracy: 0.9506, Validation Accuracy: 0.9338, Loss: 0.0597
# Epoch   5 Batch  510/538 - Train Accuracy: 0.9384, Validation Accuracy: 0.9457, Loss: 0.0615
# Epoch   5 Batch  520/538 - Train Accuracy: 0.9404, Validation Accuracy: 0.9320, Loss: 0.0650
# Epoch   5 Batch  530/538 - Train Accuracy: 0.9109, Validation Accuracy: 0.9260, Loss: 0.0823
# Epoch   6 Batch   10/538 - Train Accuracy: 0.9258, Validation Accuracy: 0.9325, Loss: 0.0661
# Epoch   6 Batch   20/538 - Train Accuracy: 0.9449, Validation Accuracy: 0.9334, Loss: 0.0660
# Epoch   6 Batch   30/538 - Train Accuracy: 0.9254, Validation Accuracy: 0.9403, Loss: 0.0699
# Epoch   6 Batch   40/538 - Train Accuracy: 0.9421, Validation Accuracy: 0.9384, Loss: 0.0584
# Epoch   6 Batch   50/538 - Train Accuracy: 0.9168, Validation Accuracy: 0.9217, Loss: 0.0602
# Epoch   6 Batch   60/538 - Train Accuracy: 0.9320, Validation Accuracy: 0.9293, Loss: 0.0661
# Epoch   6 Batch   70/538 - Train Accuracy: 0.9312, Validation Accuracy: 0.9199, Loss: 0.0695
# Epoch   6 Batch   80/538 - Train Accuracy: 0.9311, Validation Accuracy: 0.9297, Loss: 0.0759
# Epoch   6 Batch   90/538 - Train Accuracy: 0.9325, Validation Accuracy: 0.9345, Loss: 0.0694
# Epoch   6 Batch  100/538 - Train Accuracy: 0.9318, Validation Accuracy: 0.9371, Loss: 0.0597
# Epoch   6 Batch  110/538 - Train Accuracy: 0.9281, Validation Accuracy: 0.9299, Loss: 0.0736
# Epoch   6 Batch  120/538 - Train Accuracy: 0.9428, Validation Accuracy: 0.9453, Loss: 0.0508
# Epoch   6 Batch  130/538 - Train Accuracy: 0.9444, Validation Accuracy: 0.9437, Loss: 0.0661
# Epoch   6 Batch  140/538 - Train Accuracy: 0.8965, Validation Accuracy: 0.9455, Loss: 0.0799
# Epoch   6 Batch  150/538 - Train Accuracy: 0.9365, Validation Accuracy: 0.9464, Loss: 0.0537
# Epoch   6 Batch  160/538 - Train Accuracy: 0.9427, Validation Accuracy: 0.9261, Loss: 0.0607
# Epoch   6 Batch  170/538 - Train Accuracy: 0.9414, Validation Accuracy: 0.9320, Loss: 0.0638
# Epoch   6 Batch  180/538 - Train Accuracy: 0.9435, Validation Accuracy: 0.9221, Loss: 0.0582
# Epoch   6 Batch  190/538 - Train Accuracy: 0.9195, Validation Accuracy: 0.9276, Loss: 0.0880
# Epoch   6 Batch  200/538 - Train Accuracy: 0.9342, Validation Accuracy: 0.9327, Loss: 0.0623
# Epoch   6 Batch  210/538 - Train Accuracy: 0.9429, Validation Accuracy: 0.9293, Loss: 0.0651
# Epoch   6 Batch  220/538 - Train Accuracy: 0.9263, Validation Accuracy: 0.9245, Loss: 0.0661
# Epoch   6 Batch  230/538 - Train Accuracy: 0.9428, Validation Accuracy: 0.9327, Loss: 0.0638
# Epoch   6 Batch  240/538 - Train Accuracy: 0.9412, Validation Accuracy: 0.9428, Loss: 0.0700
# Epoch   6 Batch  250/538 - Train Accuracy: 0.9521, Validation Accuracy: 0.9336, Loss: 0.0641
# Epoch   6 Batch  260/538 - Train Accuracy: 0.9133, Validation Accuracy: 0.9432, Loss: 0.0743
# Epoch   6 Batch  270/538 - Train Accuracy: 0.9230, Validation Accuracy: 0.9421, Loss: 0.0577
# Epoch   6 Batch  280/538 - Train Accuracy: 0.9384, Validation Accuracy: 0.9309, Loss: 0.0515
# Epoch   6 Batch  290/538 - Train Accuracy: 0.9436, Validation Accuracy: 0.9425, Loss: 0.0631
# Epoch   6 Batch  300/538 - Train Accuracy: 0.9384, Validation Accuracy: 0.9348, Loss: 0.0589
# Epoch   6 Batch  310/538 - Train Accuracy: 0.9545, Validation Accuracy: 0.9331, Loss: 0.0721
# Epoch   6 Batch  320/538 - Train Accuracy: 0.9429, Validation Accuracy: 0.9538, Loss: 0.0633
# Epoch   6 Batch  330/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9316, Loss: 0.0618
# Epoch   6 Batch  340/538 - Train Accuracy: 0.9326, Validation Accuracy: 0.9304, Loss: 0.0696
# Epoch   6 Batch  350/538 - Train Accuracy: 0.9472, Validation Accuracy: 0.9260, Loss: 0.0724
# Epoch   6 Batch  360/538 - Train Accuracy: 0.9381, Validation Accuracy: 0.9380, Loss: 0.0629
# Epoch   6 Batch  370/538 - Train Accuracy: 0.9391, Validation Accuracy: 0.9347, Loss: 0.0626
# Epoch   6 Batch  380/538 - Train Accuracy: 0.9275, Validation Accuracy: 0.9359, Loss: 0.0591
# Epoch   6 Batch  390/538 - Train Accuracy: 0.9401, Validation Accuracy: 0.9348, Loss: 0.0568
# Epoch   6 Batch  400/538 - Train Accuracy: 0.9533, Validation Accuracy: 0.9590, Loss: 0.0606
# Epoch   6 Batch  410/538 - Train Accuracy: 0.9395, Validation Accuracy: 0.9361, Loss: 0.0621
# Epoch   6 Batch  420/538 - Train Accuracy: 0.9396, Validation Accuracy: 0.9387, Loss: 0.0638
# Epoch   6 Batch  430/538 - Train Accuracy: 0.9295, Validation Accuracy: 0.9343, Loss: 0.0658
# Epoch   6 Batch  440/538 - Train Accuracy: 0.9375, Validation Accuracy: 0.9331, Loss: 0.0660
# Epoch   6 Batch  450/538 - Train Accuracy: 0.9170, Validation Accuracy: 0.9386, Loss: 0.0803
# Epoch   6 Batch  460/538 - Train Accuracy: 0.9262, Validation Accuracy: 0.9414, Loss: 0.0721
# Epoch   6 Batch  470/538 - Train Accuracy: 0.9397, Validation Accuracy: 0.9368, Loss: 0.0651
# Epoch   6 Batch  480/538 - Train Accuracy: 0.9379, Validation Accuracy: 0.9387, Loss: 0.0564
# Epoch   6 Batch  490/538 - Train Accuracy: 0.9459, Validation Accuracy: 0.9331, Loss: 0.0560
# Epoch   6 Batch  500/538 - Train Accuracy: 0.9474, Validation Accuracy: 0.9391, Loss: 0.0457
# Epoch   6 Batch  510/538 - Train Accuracy: 0.9487, Validation Accuracy: 0.9377, Loss: 0.0540
# Epoch   6 Batch  520/538 - Train Accuracy: 0.9350, Validation Accuracy: 0.9327, Loss: 0.0636
# Epoch   6 Batch  530/538 - Train Accuracy: 0.9115, Validation Accuracy: 0.9416, Loss: 0.0738
# Epoch   7 Batch   10/538 - Train Accuracy: 0.9316, Validation Accuracy: 0.9355, Loss: 0.0658
# Epoch   7 Batch   20/538 - Train Accuracy: 0.9232, Validation Accuracy: 0.9370, Loss: 0.0637
# Epoch   7 Batch   30/538 - Train Accuracy: 0.9332, Validation Accuracy: 0.9205, Loss: 0.0730
# Epoch   7 Batch   40/538 - Train Accuracy: 0.9379, Validation Accuracy: 0.9359, Loss: 0.0589
# Epoch   7 Batch   50/538 - Train Accuracy: 0.9234, Validation Accuracy: 0.9329, Loss: 0.0609
# Epoch   7 Batch   60/538 - Train Accuracy: 0.9555, Validation Accuracy: 0.9277, Loss: 0.0556
# Epoch   7 Batch   70/538 - Train Accuracy: 0.9386, Validation Accuracy: 0.9261, Loss: 0.0610
# Epoch   7 Batch   80/538 - Train Accuracy: 0.9285, Validation Accuracy: 0.9382, Loss: 0.0727
# Epoch   7 Batch   90/538 - Train Accuracy: 0.9314, Validation Accuracy: 0.9373, Loss: 0.0749
# Epoch   7 Batch  100/538 - Train Accuracy: 0.9479, Validation Accuracy: 0.9448, Loss: 0.0551
# Epoch   7 Batch  110/538 - Train Accuracy: 0.9266, Validation Accuracy: 0.9373, Loss: 0.0726
# Epoch   7 Batch  120/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9377, Loss: 0.0535
# Epoch   7 Batch  130/538 - Train Accuracy: 0.9548, Validation Accuracy: 0.9354, Loss: 0.0625
# Epoch   7 Batch  140/538 - Train Accuracy: 0.9072, Validation Accuracy: 0.9322, Loss: 0.0882
# Epoch   7 Batch  150/538 - Train Accuracy: 0.9441, Validation Accuracy: 0.9343, Loss: 0.0661
# Epoch   7 Batch  160/538 - Train Accuracy: 0.9276, Validation Accuracy: 0.9387, Loss: 0.0592
# Epoch   7 Batch  170/538 - Train Accuracy: 0.9321, Validation Accuracy: 0.9178, Loss: 0.0755
# Epoch   7 Batch  180/538 - Train Accuracy: 0.9395, Validation Accuracy: 0.9373, Loss: 0.0699
# Epoch   7 Batch  190/538 - Train Accuracy: 0.9204, Validation Accuracy: 0.9263, Loss: 0.0980
# Epoch   7 Batch  200/538 - Train Accuracy: 0.9309, Validation Accuracy: 0.9411, Loss: 0.0584
# Epoch   7 Batch  210/538 - Train Accuracy: 0.9254, Validation Accuracy: 0.9276, Loss: 0.0782
# Epoch   7 Batch  220/538 - Train Accuracy: 0.9282, Validation Accuracy: 0.9403, Loss: 0.0714
# Epoch   7 Batch  230/538 - Train Accuracy: 0.9338, Validation Accuracy: 0.9201, Loss: 0.0756
# Epoch   7 Batch  240/538 - Train Accuracy: 0.9262, Validation Accuracy: 0.9332, Loss: 0.0755
# Epoch   7 Batch  250/538 - Train Accuracy: 0.9379, Validation Accuracy: 0.9281, Loss: 0.0750
# Epoch   7 Batch  260/538 - Train Accuracy: 0.9196, Validation Accuracy: 0.9403, Loss: 0.0706
# Epoch   7 Batch  270/538 - Train Accuracy: 0.9281, Validation Accuracy: 0.9288, Loss: 0.0829
# Epoch   7 Batch  280/538 - Train Accuracy: 0.9323, Validation Accuracy: 0.9210, Loss: 0.0714
# Epoch   7 Batch  290/538 - Train Accuracy: 0.9303, Validation Accuracy: 0.9217, Loss: 0.0684
# Epoch   7 Batch  300/538 - Train Accuracy: 0.9436, Validation Accuracy: 0.9347, Loss: 0.0793
# Epoch   7 Batch  310/538 - Train Accuracy: 0.9396, Validation Accuracy: 0.9288, Loss: 0.0824
# Epoch   7 Batch  320/538 - Train Accuracy: 0.9293, Validation Accuracy: 0.9366, Loss: 0.0683
# Epoch   7 Batch  330/538 - Train Accuracy: 0.9637, Validation Accuracy: 0.9405, Loss: 0.0586
# Epoch   7 Batch  340/538 - Train Accuracy: 0.9158, Validation Accuracy: 0.9414, Loss: 0.0674
# Epoch   7 Batch  350/538 - Train Accuracy: 0.9498, Validation Accuracy: 0.9279, Loss: 0.0739
# Epoch   7 Batch  360/538 - Train Accuracy: 0.9186, Validation Accuracy: 0.9416, Loss: 0.0686
# Epoch   7 Batch  370/538 - Train Accuracy: 0.9541, Validation Accuracy: 0.9352, Loss: 0.0658
# Epoch   7 Batch  380/538 - Train Accuracy: 0.9166, Validation Accuracy: 0.9194, Loss: 0.0694
# Epoch   7 Batch  390/538 - Train Accuracy: 0.9379, Validation Accuracy: 0.9400, Loss: 0.0600
# Epoch   7 Batch  400/538 - Train Accuracy: 0.9462, Validation Accuracy: 0.9450, Loss: 0.0731
# Epoch   7 Batch  410/538 - Train Accuracy: 0.9391, Validation Accuracy: 0.9354, Loss: 0.0718
# Epoch   7 Batch  420/538 - Train Accuracy: 0.9365, Validation Accuracy: 0.9334, Loss: 0.0620
# Epoch   7 Batch  430/538 - Train Accuracy: 0.9338, Validation Accuracy: 0.9245, Loss: 0.0649
# Epoch   7 Batch  440/538 - Train Accuracy: 0.9260, Validation Accuracy: 0.9402, Loss: 0.0685
# Epoch   7 Batch  450/538 - Train Accuracy: 0.9154, Validation Accuracy: 0.9309, Loss: 0.0858
# Epoch   7 Batch  460/538 - Train Accuracy: 0.9193, Validation Accuracy: 0.9347, Loss: 0.0767
# Epoch   7 Batch  470/538 - Train Accuracy: 0.9371, Validation Accuracy: 0.9320, Loss: 0.0652
# Epoch   7 Batch  480/538 - Train Accuracy: 0.9505, Validation Accuracy: 0.9421, Loss: 0.0648
# Epoch   7 Batch  490/538 - Train Accuracy: 0.9364, Validation Accuracy: 0.9384, Loss: 0.0707
# Epoch   7 Batch  500/538 - Train Accuracy: 0.9489, Validation Accuracy: 0.9421, Loss: 0.0499
# Epoch   7 Batch  510/538 - Train Accuracy: 0.9395, Validation Accuracy: 0.9357, Loss: 0.0657
# Epoch   7 Batch  520/538 - Train Accuracy: 0.9422, Validation Accuracy: 0.9400, Loss: 0.0658
# Epoch   7 Batch  530/538 - Train Accuracy: 0.9275, Validation Accuracy: 0.9418, Loss: 0.0784
# Epoch   8 Batch   10/538 - Train Accuracy: 0.9340, Validation Accuracy: 0.9324, Loss: 0.0660
# Epoch   8 Batch   20/538 - Train Accuracy: 0.9384, Validation Accuracy: 0.9416, Loss: 0.0735
# Epoch   8 Batch   30/538 - Train Accuracy: 0.9295, Validation Accuracy: 0.9355, Loss: 0.0692
# Epoch   8 Batch   40/538 - Train Accuracy: 0.9480, Validation Accuracy: 0.9478, Loss: 0.0630
# Epoch   8 Batch   50/538 - Train Accuracy: 0.9229, Validation Accuracy: 0.9398, Loss: 0.0728
# Epoch   8 Batch   60/538 - Train Accuracy: 0.9434, Validation Accuracy: 0.9325, Loss: 0.0569
# Epoch   8 Batch   70/538 - Train Accuracy: 0.9338, Validation Accuracy: 0.9210, Loss: 0.0580
# Epoch   8 Batch   80/538 - Train Accuracy: 0.9244, Validation Accuracy: 0.9411, Loss: 0.0690
# Epoch   8 Batch   90/538 - Train Accuracy: 0.9327, Validation Accuracy: 0.9371, Loss: 0.0730
# Epoch   8 Batch  100/538 - Train Accuracy: 0.9346, Validation Accuracy: 0.9480, Loss: 0.0614
# Epoch   8 Batch  110/538 - Train Accuracy: 0.9258, Validation Accuracy: 0.9357, Loss: 0.0750
# Epoch   8 Batch  120/538 - Train Accuracy: 0.9484, Validation Accuracy: 0.9240, Loss: 0.0542
# Epoch   8 Batch  130/538 - Train Accuracy: 0.9401, Validation Accuracy: 0.9364, Loss: 0.0610
# Epoch   8 Batch  140/538 - Train Accuracy: 0.9125, Validation Accuracy: 0.9245, Loss: 0.0958
# Epoch   8 Batch  150/538 - Train Accuracy: 0.9455, Validation Accuracy: 0.9377, Loss: 0.0573
# Epoch   8 Batch  160/538 - Train Accuracy: 0.9196, Validation Accuracy: 0.9258, Loss: 0.0600
# Epoch   8 Batch  170/538 - Train Accuracy: 0.9224, Validation Accuracy: 0.9366, Loss: 0.0753
# Epoch   8 Batch  180/538 - Train Accuracy: 0.9436, Validation Accuracy: 0.9341, Loss: 0.0662
# Epoch   8 Batch  190/538 - Train Accuracy: 0.9126, Validation Accuracy: 0.9352, Loss: 0.0891
# Epoch   8 Batch  200/538 - Train Accuracy: 0.9473, Validation Accuracy: 0.9304, Loss: 0.0589
# Epoch   8 Batch  210/538 - Train Accuracy: 0.9358, Validation Accuracy: 0.9405, Loss: 0.0647
# Epoch   8 Batch  220/538 - Train Accuracy: 0.9221, Validation Accuracy: 0.9430, Loss: 0.0640
# Epoch   8 Batch  230/538 - Train Accuracy: 0.9346, Validation Accuracy: 0.9325, Loss: 0.0581
# Epoch   8 Batch  240/538 - Train Accuracy: 0.9264, Validation Accuracy: 0.9439, Loss: 0.0783
# Epoch   8 Batch  250/538 - Train Accuracy: 0.9449, Validation Accuracy: 0.9407, Loss: 0.0610
# Epoch   8 Batch  260/538 - Train Accuracy: 0.9025, Validation Accuracy: 0.9395, Loss: 0.0723
# Epoch   8 Batch  270/538 - Train Accuracy: 0.9311, Validation Accuracy: 0.9327, Loss: 0.0605
# Epoch   8 Batch  280/538 - Train Accuracy: 0.9483, Validation Accuracy: 0.9354, Loss: 0.0526
# Epoch   8 Batch  290/538 - Train Accuracy: 0.9359, Validation Accuracy: 0.9316, Loss: 0.0527
# Epoch   8 Batch  300/538 - Train Accuracy: 0.9515, Validation Accuracy: 0.9332, Loss: 0.0594
# Epoch   8 Batch  310/538 - Train Accuracy: 0.9381, Validation Accuracy: 0.9398, Loss: 0.0670
# Epoch   8 Batch  320/538 - Train Accuracy: 0.9265, Validation Accuracy: 0.9474, Loss: 0.0569
# Epoch   8 Batch  330/538 - Train Accuracy: 0.9500, Validation Accuracy: 0.9332, Loss: 0.0635
# Epoch   8 Batch  340/538 - Train Accuracy: 0.9418, Validation Accuracy: 0.9407, Loss: 0.0627
# Epoch   8 Batch  350/538 - Train Accuracy: 0.9410, Validation Accuracy: 0.9308, Loss: 0.0699
# Epoch   8 Batch  360/538 - Train Accuracy: 0.9400, Validation Accuracy: 0.9499, Loss: 0.0566
# Epoch   8 Batch  370/538 - Train Accuracy: 0.9363, Validation Accuracy: 0.9382, Loss: 0.0610
# Epoch   8 Batch  380/538 - Train Accuracy: 0.9332, Validation Accuracy: 0.9393, Loss: 0.0572
# Epoch   8 Batch  390/538 - Train Accuracy: 0.9500, Validation Accuracy: 0.9409, Loss: 0.0608
# Epoch   8 Batch  400/538 - Train Accuracy: 0.9368, Validation Accuracy: 0.9384, Loss: 0.0724
# Epoch   8 Batch  410/538 - Train Accuracy: 0.9463, Validation Accuracy: 0.9393, Loss: 0.0715
# Epoch   8 Batch  420/538 - Train Accuracy: 0.9365, Validation Accuracy: 0.9451, Loss: 0.0666
# Epoch   8 Batch  430/538 - Train Accuracy: 0.9236, Validation Accuracy: 0.9325, Loss: 0.0722
# Epoch   8 Batch  440/538 - Train Accuracy: 0.9311, Validation Accuracy: 0.9457, Loss: 0.0778
# Epoch   8 Batch  450/538 - Train Accuracy: 0.9288, Validation Accuracy: 0.9395, Loss: 0.0747
# Epoch   8 Batch  460/538 - Train Accuracy: 0.9124, Validation Accuracy: 0.9402, Loss: 0.0747
# Epoch   8 Batch  470/538 - Train Accuracy: 0.9459, Validation Accuracy: 0.9299, Loss: 0.0603
# Epoch   8 Batch  480/538 - Train Accuracy: 0.9319, Validation Accuracy: 0.9261, Loss: 0.0681
# Epoch   8 Batch  490/538 - Train Accuracy: 0.9371, Validation Accuracy: 0.9363, Loss: 0.0563
# Epoch   8 Batch  500/538 - Train Accuracy: 0.9522, Validation Accuracy: 0.9359, Loss: 0.0536
# Epoch   8 Batch  510/538 - Train Accuracy: 0.9442, Validation Accuracy: 0.9371, Loss: 0.0607
# Epoch   8 Batch  520/538 - Train Accuracy: 0.9424, Validation Accuracy: 0.9380, Loss: 0.0638
# Epoch   8 Batch  530/538 - Train Accuracy: 0.9205, Validation Accuracy: 0.9354, Loss: 0.0800
# Epoch   9 Batch   10/538 - Train Accuracy: 0.9227, Validation Accuracy: 0.9299, Loss: 0.0739
# Epoch   9 Batch   20/538 - Train Accuracy: 0.9455, Validation Accuracy: 0.9238, Loss: 0.0643
# Epoch   9 Batch   30/538 - Train Accuracy: 0.9330, Validation Accuracy: 0.9350, Loss: 0.0701
# Epoch   9 Batch   40/538 - Train Accuracy: 0.9366, Validation Accuracy: 0.9370, Loss: 0.0575
# Epoch   9 Batch   50/538 - Train Accuracy: 0.9369, Validation Accuracy: 0.9320, Loss: 0.0670
# Epoch   9 Batch   60/538 - Train Accuracy: 0.9443, Validation Accuracy: 0.9318, Loss: 0.0640
# Epoch   9 Batch   70/538 - Train Accuracy: 0.9355, Validation Accuracy: 0.9373, Loss: 0.0663
# Epoch   9 Batch   80/538 - Train Accuracy: 0.9242, Validation Accuracy: 0.9389, Loss: 0.0656
# Epoch   9 Batch   90/538 - Train Accuracy: 0.9308, Validation Accuracy: 0.9331, Loss: 0.0775
# Epoch   9 Batch  100/538 - Train Accuracy: 0.9480, Validation Accuracy: 0.9407, Loss: 0.0561
# Epoch   9 Batch  110/538 - Train Accuracy: 0.9256, Validation Accuracy: 0.9299, Loss: 0.0696
# Epoch   9 Batch  120/538 - Train Accuracy: 0.9537, Validation Accuracy: 0.9450, Loss: 0.0456
# Epoch   9 Batch  130/538 - Train Accuracy: 0.9496, Validation Accuracy: 0.9318, Loss: 0.0668
# Epoch   9 Batch  140/538 - Train Accuracy: 0.9057, Validation Accuracy: 0.9228, Loss: 0.0879
# Epoch   9 Batch  150/538 - Train Accuracy: 0.9447, Validation Accuracy: 0.9348, Loss: 0.0624
# Epoch   9 Batch  160/538 - Train Accuracy: 0.9297, Validation Accuracy: 0.9350, Loss: 0.0557
# Epoch   9 Batch  170/538 - Train Accuracy: 0.9150, Validation Accuracy: 0.9196, Loss: 0.0714
# Epoch   9 Batch  180/538 - Train Accuracy: 0.9483, Validation Accuracy: 0.9355, Loss: 0.0695
# Epoch   9 Batch  190/538 - Train Accuracy: 0.9183, Validation Accuracy: 0.9355, Loss: 0.0948
# Epoch   9 Batch  200/538 - Train Accuracy: 0.9365, Validation Accuracy: 0.9237, Loss: 0.0658
# Epoch   9 Batch  210/538 - Train Accuracy: 0.9250, Validation Accuracy: 0.9229, Loss: 0.0758
# Epoch   9 Batch  220/538 - Train Accuracy: 0.9161, Validation Accuracy: 0.9210, Loss: 0.0668
# Epoch   9 Batch  230/538 - Train Accuracy: 0.9357, Validation Accuracy: 0.9332, Loss: 0.0673
# Epoch   9 Batch  240/538 - Train Accuracy: 0.9352, Validation Accuracy: 0.9322, Loss: 0.0689
# Epoch   9 Batch  250/538 - Train Accuracy: 0.9459, Validation Accuracy: 0.9361, Loss: 0.0670
# Epoch   9 Batch  260/538 - Train Accuracy: 0.9103, Validation Accuracy: 0.9348, Loss: 0.0777
# Epoch   9 Batch  270/538 - Train Accuracy: 0.9195, Validation Accuracy: 0.9274, Loss: 0.0705
# Epoch   9 Batch  280/538 - Train Accuracy: 0.9488, Validation Accuracy: 0.9373, Loss: 0.0584
# Epoch   9 Batch  290/538 - Train Accuracy: 0.9473, Validation Accuracy: 0.9462, Loss: 0.0620
# Epoch   9 Batch  300/538 - Train Accuracy: 0.9435, Validation Accuracy: 0.9434, Loss: 0.0687
# Epoch   9 Batch  310/538 - Train Accuracy: 0.9416, Validation Accuracy: 0.9450, Loss: 0.0743
# Epoch   9 Batch  320/538 - Train Accuracy: 0.9230, Validation Accuracy: 0.9279, Loss: 0.0631
# Epoch   9 Batch  330/538 - Train Accuracy: 0.9477, Validation Accuracy: 0.9329, Loss: 0.0579
# Epoch   9 Batch  340/538 - Train Accuracy: 0.9248, Validation Accuracy: 0.9311, Loss: 0.0633
# Epoch   9 Batch  350/538 - Train Accuracy: 0.9418, Validation Accuracy: 0.9315, Loss: 0.0700
# Epoch   9 Batch  360/538 - Train Accuracy: 0.9332, Validation Accuracy: 0.9368, Loss: 0.0634
# Epoch   9 Batch  370/538 - Train Accuracy: 0.9406, Validation Accuracy: 0.9354, Loss: 0.0569
# Epoch   9 Batch  380/538 - Train Accuracy: 0.9279, Validation Accuracy: 0.9331, Loss: 0.0577
# Epoch   9 Batch  390/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9464, Loss: 0.0624
# Epoch   9 Batch  400/538 - Train Accuracy: 0.9509, Validation Accuracy: 0.9505, Loss: 0.0666
# Epoch   9 Batch  410/538 - Train Accuracy: 0.9252, Validation Accuracy: 0.9347, Loss: 0.0661
# Epoch   9 Batch  420/538 - Train Accuracy: 0.9340, Validation Accuracy: 0.9361, Loss: 0.0705
# Epoch   9 Batch  430/538 - Train Accuracy: 0.9320, Validation Accuracy: 0.9295, Loss: 0.0650
# Epoch   9 Batch  440/538 - Train Accuracy: 0.9219, Validation Accuracy: 0.9441, Loss: 0.0722
# Epoch   9 Batch  450/538 - Train Accuracy: 0.9219, Validation Accuracy: 0.9396, Loss: 0.0914
# Epoch   9 Batch  460/538 - Train Accuracy: 0.9211, Validation Accuracy: 0.9416, Loss: 0.0725
# Epoch   9 Batch  470/538 - Train Accuracy: 0.9328, Validation Accuracy: 0.9407, Loss: 0.0698
# Epoch   9 Batch  480/538 - Train Accuracy: 0.9334, Validation Accuracy: 0.9405, Loss: 0.0674
# Epoch   9 Batch  490/538 - Train Accuracy: 0.9371, Validation Accuracy: 0.9460, Loss: 0.0652
# Epoch   9 Batch  500/538 - Train Accuracy: 0.9526, Validation Accuracy: 0.9393, Loss: 0.0538
# Epoch   9 Batch  510/538 - Train Accuracy: 0.9397, Validation Accuracy: 0.9393, Loss: 0.0592
# Epoch   9 Batch  520/538 - Train Accuracy: 0.9322, Validation Accuracy: 0.9396, Loss: 0.0703
# Epoch   9 Batch  530/538 - Train Accuracy: 0.9043, Validation Accuracy: 0.9341, Loss: 0.0771
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    unk_id = vocab_to_int['<UNK>']
    temp = [vocab_to_int.get(word) if vocab_to_int.get(word)!=None else unk_id for word in sentence.split()]
    return temp


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
#translate_sentence = 'he saw a old yellow truck .'
translate_sentence = 'she drove a yellow truck'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [183, 63, 32, 178, 181]
#   English Words: ['she', 'drove', 'a', 'yellow', 'truck']
#
# Prediction
#   Word Ids:      [116, 235, 281, 203, 311, 275, 252, 308, 282, 227]
#   French Words: elle voulait aller au mois de juin dernier en californie

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
